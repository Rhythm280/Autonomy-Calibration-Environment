# %% [markdown]
# # OpenEnv Autonomy Calibration — Training Notebook
#
# This notebook demonstrates how to train a calibrated AI agent using **GRPO (Group Relative Policy Optimization)** through the Hugging Face TRL framework.
#
# ### 1. Install Dependencies

# %%
# !pip install --upgrade numpy trl transformers accelerate peft torchao bitsandbytes requests matplotlib
print('✅ Done. Please Restart Session if this is your first run!')

# %% [markdown]
# ### 2. Configure the Training Loop
# The training script `train_rl.py` connects to the live environment API to fetch rewards and update the policy.

# %%
# In a real Colab, you would clone the repo and run:
# !python3 train_rl.py
